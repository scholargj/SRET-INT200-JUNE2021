# %% [markdown]
# <a href="https://colab.research.google.com/github/scholargj/SRET-INT200-JUNE2021/blob/master/Getting_started_with_Angular_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Front-End Development with Angular**
#
# **Dr. Jayanthi G, SRET.**

# %% [markdown]
# #Step 1: Getting Started with Angular in Windows 10
# 1. Install Node.js, the Node Packet Manager (NPM) client is the part of Node.js
# 2. Get into the [download page](https://nodejs.org/en/download/)

# %% [markdown]
# ![Node.jsdownload.png](data:image/png;base64,...)

# %% [markdown]
# Follow the installer wizard for installation. If you need help, [click here](https://ccbill.com/kb/install-angular-on-windows)

# %% [markdown]
# # Check the installation of Node

# %% [markdown]
# To check the version of node installed give the below command
#
# ```
# node -v
# ```

# %% [markdown]
# The system confirms the version of node.js as 14.16.0
#
# #Check the version of NPM installed

# %% [markdown]
# ![node.png](data:image/png;base64,...)

# %% [markdown]
# ![node2.png](data:image/png;base64,...)

# %% [markdown]
# #Step 2: Install Typescript(TS)

# %% [markdown]
# Install TypeScript using the command given below,
# ```
# npm install -g typescript
# ```
#
# Verify the installed version using the command,
#
#
# ```
# tsc -v
# ```
# TypeScript version installed in 4.2.3

# %% [markdown]
# ![TS.png](data:image/png;base64,...)

# %% [markdown]
# # Step 3: Install Angular CLI
# The Angular command-line interface (CLI) tool allows you to initialize, develop, and manage your Angular applications. You can use the NPM package manager to install the Angular CLI.
#
# Access the Windows Command Prompt and enter the following command:
#
# ```
# npm install -g @angular/cli
# ```
#
# 2. Once all packages have been added, verify the installed version:
#
# `ng --version`
#
# The Angular CLI version is 11.2.5.

# %%
F:\>ng --version

     _                      _                 ____ _     ___
    / \   _ __   __ _ _   _| | __ _ _ __     / ___| |   |_ _|
   / △ \ | '_ \ / _` | | | | |/ _` | '__|   | |   | |    | |
  / ___ \| | | | (_| | |_| | | (_| | |      | |___| |___ | |
 /_/   \_\_| |_|\__, |\__,_|_|\__,_|_|       \____|_____|___|
                |___/


Angular CLI: 11.2.5
Node: 14.16.0
OS: win32 x64

Angular:
...
Ivy Workspace:

Package                      Version
------------------------------------------------------
@angular-devkit/architect    0.1102.5 (cli-only)
@angular-devkit/core         11.2.5 (cli-only)
@angular-devkit/schematics   11.2.5 (cli-only)
@schematics/angular          11.2.5 (cli-only)
@schematics/update           0.1102.5 (cli-only)
# Out:
#   File "<ipython-input-1-107954b86a33>", line 1
#     F:\>ng --version
#                     ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# #4. Start an Angular Project

# %% [markdown]
# Use the Angular CLI to start a new Angular project.
#
# In this example, the name of the project is FirstApp.
#
# **Note:** You are free to use the name of your choice for your project name. Type the following command in your Windows Command Prompt:
#
# `ng new FirstApp`
#
# Navigate to root folder of project in this example helloworld.
#
# `F:\helloworld>`
#
# use the command below to build and serve the application
#
# `F:\helloworld>ng serve -o`

# %%
F:\helloworld>ng serve -o
√ Browser application bundle generation complete.

Initial Chunk Files   | Names         |      Size
vendor.js             | vendor        |   2.69 MB
polyfills.js          | polyfills     | 474.96 kB
styles.css, styles.js | styles        | 347.01 kB
main.js               | main          |  24.13 kB
runtime.js            | runtime       |   6.15 kB

                      | Initial Total |   3.52 MB

Build at: 2021-05-01T14:44:14.920Z - Hash: 69a8ed65c18b1a5a3270 - Time: 28966ms

** Angular Live Development Server is listening on localhost:4200, open your browser on http://localhost:4200/ **


√ Compiled successfully.
# Out:
#   File "<ipython-input-1-4221d5b9c8de>", line 1
#     F:\helloworld>ng serve -o
#                              ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# **Angular Live Development Server is listening on localhost:4200, open your browser on http://localhost:4200/**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Open Visual Studio Code
# 2. Open folder and navigate to the Angular project folder created in step 3 and 4, in this example, helloworld folder

# %% [markdown]
# ![Angularscreen.png](data:image/png;base64,...)

# %% [markdown]
# The components of Angular application are
# Ng Module
# The core component
#
# The folder src-->app contains following files,
# 1. app.component. html
# 2. app.component.ts
# 3. app.module.ts
# 4. app.routing.module.ts
# 5. app.component.css

# %% [markdown]
# # References
# https://angular.io/start
#
# # Text Book
# 1. Nathan Murray, Ari Lerner,Felipe Coury, Carlos Taborda, ng-book: The Complete Guide to Angular 4, 2017

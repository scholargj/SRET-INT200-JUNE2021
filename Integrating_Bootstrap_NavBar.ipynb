# %% [markdown]
# <a href="https://colab.research.google.com/github/scholargj/SRET-INT200-JUNE2021/blob/master/Integrating_Bootstrap_NavBar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Integration of Boorstrap NavBar in Aungular Project
#
#  This notebook will demonstrate the following in Angular project
#
# 1. Installing or Adding bootstrap to a angular project.
# 2. Create components.
# 3. Creating NavBar to use components
# 4. Running the application.
#
#
# Authored by
#
# **Dr. G. Jayanthi.,**
#
# Faculty of Engineering and Technology,
#
# SRET

# %% [markdown]
# #**1. Installing or Adding Bootstrap in Angular**

# %% [markdown]
# #Method - 1 using npm install
#
# `npm install bootstrap jquery popper.js –-save`
#
# Installs Bootstrap, jQuery, and JavaScript

# %%
PS C:\Users\gj\Component> npm install bootstrap jquery popper.js --save
npm WARN deprecated popper.js@1.16.1: You can find the new Popper v2 at @popperjs/core, this package is dedicated to the legacy v1       
npm WARN optional SKIPPING OPTIONAL DEPENDENCY: fsevents@2.3.2 (node_modules\fsevents):
npm WARN notsup SKIPPING OPTIONAL DEPENDENCY: Unsupported platform for fsevents@2.3.2: wanted {"os":"darwin","arch":"any"} (current: {"os":"win32","arch":"x64"})
npm WARN optional SKIPPING OPTIONAL DEPENDENCY: fsevents@1.2.13 (node_modules\watchpack-chokidar2\node_modules\fsevents):
npm WARN notsup SKIPPING OPTIONAL DEPENDENCY: Unsupported platform for fsevents@1.2.13: wanted {"os":"darwin","arch":"any"} (current: {"os":"win32","arch":"x64"})
npm WARN optional SKIPPING OPTIONAL DEPENDENCY: fsevents@1.2.13 (node_modules\webpack-dev-server\node_modules\fsevents):
npm WARN notsup SKIPPING OPTIONAL DEPENDENCY: Unsupported platform for fsevents@1.2.13: wanted {"os":"darwin","arch":"any"} (current: {"os":"win32","arch":"x64"})

+ bootstrap@4.6.0
+ jquery@3.6.0
+ popper.js@1.16.1
added 2 packages from 3 contributors, updated 1 package and audited 1620 packages in 17.375s

97 packages are looking for funding
  run `npm fund` for details

found 0 vulnerabilities

PS C:\Users\gj\Component>
# Out:
#   File "<ipython-input-6-96ad565e0703>", line 1
#     PS C:\Users\gj\Component> npm install bootstrap jquery popper.js --save
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# #How to ensure bootstrap is installed?
#
# Check the folder *bootstrap* under *node_modules* in your project folder as shown below.

# %% [markdown]
# ![installedbootstrap.png](data:image/png;base64,...)

# %% [markdown]
# # Methods - 2
#
# Alternatively add the links using Bootstrap CDN, follow the steps given below,

# %%
<html>

<head>
  <meta charset="utf-8">
  <title>Component</title>
  <base href="/">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <link rel="icon" type="image/x-icon" href="favicon.ico">
  <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
</head>
<body>
  <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/js/bootstrap.min.js" integrity="sha384-wfSDF2E50Y2D1uUdj0O3uMBJnjuUD4Ih7YwaYd1iqfktj0Uod8GCExl3Og8ifwB6" crossorigin="anonymous"></script>

  <script src="https://code.jquery.com/jquery-3.4.1.slim.min.js" integrity="sha384-J6qa4849blE2+poT4WnyKhv5vZF5SrPo0iEjwBvKU7imGFAV0wwj1yYfoRSJoZ+n" crossorigin="anonymous"></script>
<script src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" crossorigin="anonymous"></script>
  <app-root></app-root>
</body>
</html>
# Out:
#   File "<ipython-input-5-0e10c9e73ae9>", line 1
#     <html>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# **The index.html file in this project folder looks like this**
#
# 1. **Copy the link tag shown below**
#
# ```
# <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
# ```
#
# and place it at the end of head tag.
#
# 2. **Copy the script tag shown below**,and place it at the beginnning of the body tag.
#
# ```
# <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/js/bootstrap.min.js" integrity="sha384-wfSDF2E50Y2D1uUdj0O3uMBJnjuUD4Ih7YwaYd1iqfktj0Uod8GCExl3Og8ifwB6" crossorigin="anonymous"></script>`
# ```
#
#  3. **Copy the remaining two script tags given below**, place them at the end of bootstrap script tags as shown below.
#
#
# ```
# <script src="https://code.jquery.com/jquery-3.4.1.slim.min.js" integrity="sha384-J6qa4849blE2+poT4WnyKhv5vZF5SrPo0iEjwBvKU7imGFAV0wwj1yYfoRSJoZ+n" crossorigin="anonymous"></script>
# <script src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" crossorigin="anonymous"></script>
# ```

# %% [markdown]
# Save the files, and run the command ng serve

# %% [markdown]
# # 2. Creating components
# 1. Go to documentation [Documentation](https://getbootstrap.com/docs/4.0/components/navbar/)
#
# 2. Steps in creating the following three Components inside this project
#
# Courses : This component is required to display the list of courses offered.
# Results : This component is required to display results.
# Projects: This component may be used for displaying titles of projects done by students.
#
# use the commands given below,
#
# `ng generate component courses`
#
# `ng generate component Results`
#
# `ng generate component Projects`
#
#
# Check the terminal in Angular for results as shown below.

# %%
PS C:\Users\gj\Component> ng generate component courses
CREATE src/app/courses/courses.component.html (22 bytes)
CREATE src/app/courses/courses.component.spec.ts (633 bytes)
CREATE src/app/courses/courses.component.ts (279 bytes)
CREATE src/app/courses/courses.component.css (0 bytes)
UPDATE src/app/app.module.ts (553 bytes)
PS C:\Users\gj\Component> ng generate component Results
CREATE src/app/results/results.component.html (22 bytes)
CREATE src/app/results/results.component.spec.ts (633 bytes)
CREATE src/app/results/results.component.ts (279 bytes)
CREATE src/app/results/results.component.css (0 bytes)
UPDATE src/app/app.module.ts (639 bytes)
PS C:\Users\gj\Component> ng generate component Projects
CREATE src/app/projects/projects.component.html (23 bytes)
CREATE src/app/projects/projects.component.spec.ts (640 bytes)
CREATE src/app/projects/projects.component.ts (283 bytes)
CREATE src/app/projects/projects.component.css (0 bytes)
UPDATE src/app/app.module.ts (729 bytes)
PS C:\Users\gj\Component>
# Out:
#   File "<ipython-input-1-91b0d749fe2c>", line 1
#     PS C:\Users\gj\Component> ng generate component courses
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Refer to figure given below, the three components are seen in seperate folders within**
#
# root-->src-->app-->
#
# Courses
# Results
# Projects

# %% [markdown]
# ![3 comp.png](data:image/png;base64,...)

# %% [markdown]
# Import all the components to the app.module.ts file and add them within the declarations array as shown below:
#
# **Note: This is done by ng by itself, not required to add them manually**.

# %% [markdown]
# ![app.module.ts.png](data:image/png;base64,...)

# %% [markdown]
# Open the app-routing module.ts file and add paths to each of these components as shown below:
#
#
#
# ![app.routing.ts.png](data:image/png;base64,...)

# %% [markdown]
# #3. Adding NavBar in bootstrap

# %% [markdown]
# Open *app.component.html* file of each of your components and add any Bootstrap element of your choice.
#
# The reason to add a Navbar to the app.component.html file is for it to be displayed on each page of my website.
#
# **Note: Use Bootstrap Documentation for NavBar code.**

# %%
<nav class="navbar navbar-expand-lg navbar-light bg-light">
  <a class="navbar-brand" href="http://www.sret.edu.in">Sri Ramachandra Engineering and Technology</a>
  <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
    <span class="navbar-toggler-icon"></span>
  </button>
<div class="collapse navbar-collapse" id="navbarNav">
<ul class="navbar-nav">
<li class="nav-item active">
        <a class="nav-link" href="http://www.youtube.com">Courses<span class="sr-only">(current)</span></a>
      </li>
<li class="nav-item">
        <a class="nav-link" href="#">Results</a>
      </li>
<li class="nav-item">
        <a class="nav-link" href="#">Projects</a>
      </li>
    </ul>
</div>
</nav>

# %% [markdown]
# # 4. Running the application to see NavBar in Angular Project

# %% [markdown]
# ![Angularnavbar.png](data:image/png;base64,...)

# %% [markdown]
# # Example 2: Integrating bootstrap Navbar in Angular Project

# %% [markdown]
# 1. Create Angular project **`ng new MyPage`**.
# 2. Code for **`app.component.html`** is given below.
#
# The class included is `"navbar navbar-expand-lg navbar-light bg-light"`.
#
# **`href="#"`** refer to hyperlink for each item on the navigation bar.

# %%
<nav class="navbar navbar-expand-lg navbar-light bg-light">
  <a class="navbar-brand logo" href="#">Medical Imaging Research</a>
  <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">
    <span class="navbar-toggler-icon"></span>
  </button>

  <div class="collapse navbar-collapse" id="navbarSupportedContent">
    <ul class="navbar-nav mr-auto">
      <li class="nav-item active">
        <a class="nav-link" href="#">Home <span class="sr-only">(current)</span></a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Data Repository</a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Applications</a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Practice</a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Services</a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Publications</a>
      </li>
    </ul>
    <ul class="navbar-nav ">
     
      <li class="nav-item dropdown">
        <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button" aria-haspopup="true"
        aria-expanded="false">Research Profile</a>
        <div class="dropdown-menu">
          <a class="dropdown-item" href="#">User2</a>
          <a class="dropdown-item" href="#">User3</a>
          
        </div>
      </li>
    </ul>
  </div>
</nav>



<h1 style="font-size:30px;background-color:rgb(30, 255, 199); color:brown"> Hello, Welcome to my page</h1>
<router-outlet></router-outlet>

# %% [markdown]
# The code for **`app.component.ts`** is given below,

# %%
import { Component } from '@angular/core';

@Component({
  selector: 'app-root',
  templateUrl: './app.component.html',
  styleUrls: ['./app.component.css']
})
export class AppComponent {
  title = 'My Page';
  
}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Example 3: Navigations and footer page**

# %% [markdown]
# `app.component.html`

# %%
<nav class="navbar navbar-expand-lg navbar-light bg-light">
  <a class="navbar-brand logo" href="#">Medical Imaging Research</a>
  <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation">
    <span class="navbar-toggler-icon"></span>
  </button>

  <div class="collapse navbar-collapse" id="navbarSupportedContent">
    <ul class="navbar-nav mr-auto">
      <li class="nav-item active">
        <a class="nav-link" href="#">Home <span class="sr-only">(current)</span></a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Data Repository</a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Applications</a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Practice</a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Services</a>
      </li>
      <li class="nav-item">
        <a class="nav-link" href="#">Publications</a>
      </li>
    </ul>
    <ul class="navbar-nav ">
     
      <li class="nav-item dropdown">
        <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button" aria-haspopup="true"
        aria-expanded="false">Research Profile</a>
        <div class="dropdown-menu">
          <a class="dropdown-item" href="#">User2</a>
          <a class="dropdown-item" href="#">User3</a>
          
        </div>
      </li>
    </ul>
  </div>
</nav>

<h1 style="font-size:30px;background-color:rgb(30, 255, 199); color:brown"> Hello, Welcome to my page</h1>

<footer class="footer">
  <div class="container-fluid">
      <nav class="pull-left">
          <ul>
              <li>
                  <a href="#">
                      About Us
                  </a>
              </li>
              <li>
                  <a href="#">
                      Management and Administration 
                  </a>
              </li>
              <li>
                  <a href="#">
                      Portfolio
                  </a>
              </li>
              <li>
                  <a href="#">
                      Contact Us
                  </a>
              </li>
          </ul>
      </nav>
      <p class="copyright pull-right"> &copy;{{test | date: 'yyyy'}} 
    <a href="http://www.sret.edu.in">Sri Ramachandra Engineering and Technology </a>, specially made to provide better service </p>
  </div>
</footer>


<router-outlet></router-outlet>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #References
# **Text Book**
# 1. Nathan Murray, Ari Lerner,Felipe Coury, Carlos Taborda, ng-book: The Complete Guide to Angular 4, 2017
#
# **Repository**
#
# [Navigation Bar](https://gist.github.com/Ivy-Walobwa/567d3438fceddb6fb15f1a7b51aeca25)

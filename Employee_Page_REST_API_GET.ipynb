# %% [markdown]
# <a href="https://colab.research.google.com/github/scholargj/SRET-INT200-JUNE2021/blob/master/Employee_Page_REST_API_GET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Full stack web development - Display Employee Page with details in Tabular Form using REST API GET method**
#
#
# *Authored by*
#
# **Dr. Jayanthi Ganapathy,**
#
# Assistant Professor,
#
# Faculty of Engineering and Technology,
#
# Sri Ramachandra Institute of Higher Education and Research,
#
# Chennai - 600 116.

# %% [markdown]
# **Points to Note:**
#
# This notebook will explain the complete steps on how to fetch the data from SQLite and display in the Department page in Tabular form.
#
# Refer to the GITHUB post as mentioned below.
#
# Step-1. [To create Angular project, necessary Components and services, Click here](https://github.com/scholargj/SRET-INT200-JUNE2021/blob/master/RESTAPImethods_AngularProject.ipynb)
#
#
# Step-2. [Add Bootstrap and Routing, Click here](https://github.com/scholargj/SRET-INT200-JUNE2021/blob/master/Bootstrap%26Routing_Fullstack.ipynb)(Continuation of Step-1)

# %% [markdown]
# # **Step-3 Code the Show-Employee Component**

# %% [markdown]
# 1. import the sharedService created in step -1
#
# `import { SharedService } from 'src/app/shared.service';`
#
# 2. Create a constructor
#
# ```
# constructor(private service:SharedService) { }
# ```
#
# 3. Create a empty list to store the data
#
# `EmployeeList:any=[];`
#
#
# 4. Create a method to refresh the Department list. This calls the REST API GET method by passing the URL defined in Django project
#
# ```
# refreshEmpList()
# {
#   this.service.getEmpList().subscribe(data=>{
#     this.EmployeeList=data;});
# }
# ```
# **subscribe()** method fetches the data to DepartmentList using Asynchronous operation as indicated by symbol =>
#
# 5. Call the refreshDepList() in **ngOnInit()** method as this method loads first when component is called.
# ```
# ngOnInit(): void
# {
#     this.refreshEmpList();
# }
# ```

# %% [markdown]
# **show-emp.component.ts** file

# %%
import { Component, OnInit } from '@angular/core';
import { SharedService } from 'src/app/shared.service';
@Component({
  selector: 'app-show-emp',
  templateUrl: './show-emp.component.html',
  styleUrls: ['./show-emp.component.css']
})
export class ShowEmpComponent implements OnInit {

  constructor(private service:SharedService) { }
  //create an empty list for department
  EmployeeList:any=[];
  ModalTitle:string | undefined;
  ActivateAddEditEmpComp:boolean=false;
  emp:any;

ngOnInit(): void 
{
    this.refreshEmpList();
}
refreshEmpList()
{
  this.service.getEmpList().subscribe(data=>{
    this.EmployeeList=data;});
}
}

# %% [markdown]
# Build the nodeJS and run the development server to serve the application at localhost:4200

# %% [markdown]
# # **Step-4 Employee page to display the details in tabular form**

# %% [markdown]
# 1. Create table with headers Employee Id and Employee Name with options to edit and delete.
#
#
# 2. Edit and Delete buttons are required to Add, update and delete details using REST API POST, PUT and DELETE methods
#
#
# 3. Using `*ngFor` directive populate the table from DepartmentList
#
# The **show-emp.component.html** file is given below,

# %%
<table class="table table-striped"> 
    <thead>
        <tr>
            <th>EmployeeId</th>
            <th>EmployeeName</th>
            <th>Department</th>
            <th>DateOfJoining</th>
            <th>Options</th>
        </tr>
    </thead>
    <tbody>
        <tr *ngFor="let dataItem of EmployeeList">
            <td>{{dataItem.EmployeeId}}</td>
            <td>{{dataItem.EmployeeName}}</td>
            <td>{{dataItem.Department}}</td>
            <td>{{dataItem.DateOfJoining}}</td>
            <td>
                <button type="button" class="btn btn-light mr-1">
                Edit
                </button>

                <button type="button" class="btn btn-light mr-1">
                Delete
                </button>
            </td>
        </tr>
    </tbody>
</table>

# %% [markdown]
# Copy `app-show-emp` from `selector: 'app-show-emp',` in **show-emp.component.ts**. This is the selector for this component.
#
# Include the selector in **employee.component.html** as shown below,
#
#
# `<app-show-emp></app-show-emp>`

# %% [markdown]
# This will display the employee page on `localhost:4200/employee` as shown below

# %% [markdown]
# ![image.png](data:image/png;base64,...)
